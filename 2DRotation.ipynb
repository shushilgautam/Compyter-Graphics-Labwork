# %%
import matplotlib.pyplot as plt
from math import sin,cos,radians
import os
print(os.getcwd())
def rotate(x1,y1,x2,y2,angle,ax,ay):
    x_list=[x1,x2]
    y_list=[y1,y2]
    tempx=[x1,x2]
    tempy=[y1,y2]
    
    print("Point Before Rotation :")
    print(f"{x_list[0],y_list[0]} {x_list[1],y_list[1]}")
    plt.plot(x_list,y_list,marker="o",label="Before rotation")
    # rotation about origin is given in formula
    angle=radians(angle)
    x_list[0]=round(x1*cos(angle)-y1*sin(angle))
    y_list[0]=round(x1*sin(angle)+y1*cos(angle))
    x_list[1]=round(x2*cos(angle)-y2*sin(angle))
    y_list[1]=round(x2*sin(angle)+y2*cos(angle))
    print("Point After Rotation about origin:")
    print(f"{x_list[0],y_list[0]} {x_list[1],y_list[1]}")
    plt.plot(x_list,y_list,marker="o",label="Rotation about origin")
    # rotation about arbiratory point = A'+ arbiratory point
    tempx[0]-=ax
    tempy[0]-=ay
    tempx[1]-=ax
    tempy[1]-=ay
    
    x_list[0]=round(tempx[0]*cos(angle)-tempy[0]*sin(angle))
    y_list[0]=round(tempx[0]*sin(angle)+tempy[0]*cos(angle))
    x_list[1]=round(tempx[1]*cos(angle)-tempy[1]*sin(angle))
    y_list[1]=round(tempx[1]*sin(angle)+tempy[1]*cos(angle))
    x_list[0]+=ax
    y_list[0]+=ay
    x_list[1]+=ax
    y_list[1]+=ay
    print("Point After Rotation about arbitrary point : ")
    print(f"{x_list[0],y_list[0]} {x_list[1],y_list[1]}")
    plt.plot(x_list,y_list,marker="o",label="Rotation about arbitrary point")
    plt.plot(ax,ay,marker="o",label="Arbitrary Point")    
    
x1,y1=map(int,input("Enter the point x1 and y1 :").split())
x2,y2=map(int,input("Enter the point x2 and y2 :").split())
angle=int(input("Enter the angle in degree :"))
ax,ay=map(int,input("Enter the arbitrary point ax and ay :").split())
rotate(x1,y1,x2,y2,angle,ax,ay)
plt.legend()
plt.title("Rotation")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.grid(True)
plt.show()
# Out:
# D:\Programming\Python programs\Sushil Gautam\Computer Graphics
# Enter the point x1 and y1 : 5 5
# Enter the point x2 and y2 : 10 5
# Enter the angle in degree : 45
# Enter the arbitrary point ax and ay : 7 5
# Point Before Rotation :
# (5, 5) (10, 5)
# Point After Rotation about origin:
# (0, 7) (4, 11)
# Point After Rotation about arbitrary point :
# (6, 4) (9, 7)
