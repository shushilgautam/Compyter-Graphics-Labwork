# %%
import matplotlib.pyplot as plt

def find_symmetry(nex_x, nex_y, center_x, center_y):
    print(f"({nex_y+center_x},{nex_x+center_y})",end=" ")
    plt.plot(nex_y+center_x, nex_x+center_y, '.', color='red')
    print(f"\t({nex_x+center_x},{nex_y+center_y})",end=" ")
    plt.plot(nex_x+center_x, nex_y+center_y, '.', color='red')
    print(f"\t({nex_x+center_x},{-nex_y+center_y})",end=" ")
    plt.plot(nex_x+center_x, -nex_y+center_y, '.', color='red')
    print(f"\t({nex_y+center_x},{-nex_x+center_y})",end=" ")
    plt.plot(nex_y+center_x, -nex_x+center_y, '.', color='red')
    print(f"\t({-nex_y+center_x},{-nex_x+center_y})",end=" ")
    plt.plot(-nex_y+center_x, -nex_x+center_y, '.', color='red')
    print(f"\t({-nex_x+center_x},{-nex_y+center_y})",end=" ")
    plt.plot(-nex_x+center_x, -nex_y+center_y, '.', color='red')
    print(f"\t({-nex_x+center_x},{nex_y+center_y})",end=" ")
    plt.plot(-nex_x+center_x, nex_y+center_y, '.', color='red')
    print(f"\t({-nex_y+center_x},{nex_x+center_y})")
    plt.plot(-nex_y+center_x, nex_x+center_y, '.', color='red')

radius = float(input("Enter the radius of the cirlce: "))
center_x, center_y = map(float, input("Enter the co-ordinate of center of the circle: ").split())

nex_x = 0
nex_y = radius

p = 1 - radius
k = 0
print("k\tpk\t1st\t\t2nd\t\t3rd\t\t4th\t\t5th\t\t6th\t\t7th\t\t8th")
print(f"{k}\t{p}\t{2*nex_x}\t{2*nex_y}\t", end="")
find_symmetry(nex_x, nex_y, center_x, center_y)

while(nex_x<=nex_y):
    k+=1
    nex_x +=1
    if(p<0):
        p += 2*nex_x +1
    else:
        nex_y -=1
        p+=2*nex_x +1 -2*nex_y
    
    print(f"{k}\t{p}\t{2*nex_x}\t{2*nex_y}\t", end="")    
    find_symmetry(nex_x, nex_y, center_x, center_y)
    
plt.show()
plt.close()
# Out:
# Enter the radius of the cirlce:  10
# Enter the co-ordinate of center of the circle:  0 0
# k	p	2x(k+1)	2y(k+1)	1st		2nd		3rd		4th		5th		6th		7th		8th
# 0	-9.0	0	20.0	(10.0,0.0) 	(0.0,10.0) 	(0.0,-10.0) 	(10.0,0.0) 	(-10.0,0.0) 	(0.0,-10.0) 	(0.0,10.0) 	(-10.0,0.0)
# 1	-6.0	2	20.0	(10.0,1.0) 	(1.0,10.0) 	(1.0,-10.0) 	(10.0,-1.0) 	(-10.0,-1.0) 	(-1.0,-10.0) 	(-1.0,10.0) 	(-10.0,1.0)
# 2	-1.0	4	20.0	(10.0,2.0) 	(2.0,10.0) 	(2.0,-10.0) 	(10.0,-2.0) 	(-10.0,-2.0) 	(-2.0,-10.0) 	(-2.0,10.0) 	(-10.0,2.0)
# 3	6.0	6	20.0	(10.0,3.0) 	(3.0,10.0) 	(3.0,-10.0) 	(10.0,-3.0) 	(-10.0,-3.0) 	(-3.0,-10.0) 	(-3.0,10.0) 	(-10.0,3.0)
# 4	-3.0	8	18.0	(9.0,4.0) 	(4.0,9.0) 	(4.0,-9.0) 	(9.0,-4.0) 	(-9.0,-4.0) 	(-4.0,-9.0) 	(-4.0,9.0) 	(-9.0,4.0)
# 5	8.0	10	18.0	(9.0,5.0) 	(5.0,9.0) 	(5.0,-9.0) 	(9.0,-5.0) 	(-9.0,-5.0) 	(-5.0,-9.0) 	(-5.0,9.0) 	(-9.0,5.0)
# 6	5.0	12	16.0	(8.0,6.0) 	(6.0,8.0) 	(6.0,-8.0) 	(8.0,-6.0) 	(-8.0,-6.0) 	(-6.0,-8.0) 	(-6.0,8.0) 	(-8.0,6.0)
# 7	6.0	14	14.0	(7.0,7.0) 	(7.0,7.0) 	(7.0,-7.0) 	(7.0,-7.0) 	(-7.0,-7.0) 	(-7.0,-7.0) 	(-7.0,7.0) 	(-7.0,7.0)
# 8	11.0	16	12.0	(6.0,8.0) 	(8.0,6.0) 	(8.0,-6.0) 	(6.0,-8.0) 	(-6.0,-8.0) 	(-8.0,-6.0) 	(-8.0,6.0) 	(-6.0,8.0)
