# %%
import matplotlib.pyplot as plt
import os
print(os.getcwd())
def translate(x1,x2,y1,y2,tx,ty):
    x_list=[x1,x2]
    y_list=[y1,y2]
    print("Point Before translation :",end="")
    print(f"{x_list[0],y_list[0]} {x_list[1],y_list[1]}")
    plt.plot(x_list,y_list,marker="o",label="Before translation")
    x_list=[x1+tx,x2+tx]
    y_list=[y1+ty,y2+ty]
    print("Point After translation :",end="")
    print(f"{x_list[0],y_list[0]} {x_list[1],y_list[1]}")
    plt.plot(x_list,y_list,marker="o",label="After translation")
    plt.title("Translation")
    plt.legend()
    plt.xlabel("x-axis")
    plt.ylabel("y-axis")
    plt.show()
print("Enter line co-ordinates:")
x1,y1=map(int,input("Enter the point x1 and y1 :").split())
x2,y2=map(int,input("Enter the point x2 and y2 :").split())
tx,ty=map(int,input("Enter the tranlation factor tx,ty :").split())

translate(x1,x2,y1,y2,tx,ty)
# Out:
# D:\Programming\Python programs\Sushil Gautam\Computer Graphics
# Enter line co-ordinates:
# Enter the point x1 and y1 : 3 1
# Enter the point x2 and y2 : 7 3
# Enter the tranlation factor tx,ty : 2 5
# Point Before translation :(3, 1) (7, 3)
# Point After translation :(5, 6) (9, 8)
